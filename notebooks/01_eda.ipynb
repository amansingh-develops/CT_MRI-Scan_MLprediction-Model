# %% [markdown]
# # Phase 1: Exploratory Data Analysis
# This notebook will utilize our EDA modules written in `src/eda` to run statistical and visual data analysis.

# %%
import sys
import os

# Ensure the src module is heavily available to the notebook path
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# ### 1. Basic Statistical Analysis

# %%
from src.eda.eda_basic import analyze_csv

analyze_csv('../data/lits_train.csv', 'Train Dataset')
analyze_csv('../data/lits_test.csv', 'Test Dataset')

# %% [markdown]
# ### 2. Deep Visual Dive
# Generating statistics plots and samples. Plots are inherently saved inside `/results/eda/` folder natively via the functions!

# %%
from src.eda.eda_visual import plot_slice_type_distribution, visualize_dataset_samples, plot_pixel_intensity_histogram

plot_slice_type_distribution(csv_path='../data/lits_train.csv')
plot_pixel_intensity_histogram(csv_path='../data/lits_train.csv', data_root='../data')
visualize_dataset_samples(csv_path='../data/lits_train.csv', data_root='../data')
