# %% [markdown]
# # Liver AI Project - Data Exploration
#
# This notebook contains exploratory data analysis for the liver AI project.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Set up data paths
DATA_DIR = '../data'
RAW_CT_DIR = os.path.join(DATA_DIR, 'raw', 'CT')
RAW_MRI_DIR = os.path.join(DATA_DIR, 'raw', 'MRI')
PROCESSED_IMAGES_DIR = os.path.join(DATA_DIR, 'processed', 'images')
PROCESSED_MASKS_DIR = os.path.join(DATA_DIR, 'processed', 'masks')

# %% [markdown]
# ## Data Loading and Exploration
